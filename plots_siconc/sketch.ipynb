# %%
# !pip install --quiet fpdf2

# %%
from pdf import make_gallery_pdf         # or however you import

make_gallery_pdf(
    folder   = ".",                      # ← current working dir
    pdf_name = "siconc_gallery.pdf",
    ncols    = 2, nrows = 3,
    recursive=True                       # include sub-folders
)
# Out:
# ✅  Saved siconc_gallery.pdf
